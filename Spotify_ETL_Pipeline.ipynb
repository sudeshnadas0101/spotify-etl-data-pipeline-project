# %%
pip install spotipy --upgrade
# Out:
# Requirement already satisfied: spotipy in c:\users\dassu\anaconda3\lib\site-packages (2.25.0)Note: you may need to restart the kernel to use updated packages.
#
# Collecting spotipy
#   Downloading spotipy-2.25.1-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: redis>=3.5.3 in c:\users\dassu\anaconda3\lib\site-packages (from spotipy) (5.2.1)
# Requirement already satisfied: requests>=2.25.0 in c:\users\dassu\anaconda3\lib\site-packages (from spotipy) (2.32.2)
# Requirement already satisfied: urllib3>=1.26.0 in c:\users\dassu\anaconda3\lib\site-packages (from spotipy) (2.2.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\dassu\anaconda3\lib\site-packages (from requests>=2.25.0->spotipy) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dassu\anaconda3\lib\site-packages (from requests>=2.25.0->spotipy) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dassu\anaconda3\lib\site-packages (from requests>=2.25.0->spotipy) (2024.6.2)
# Downloading spotipy-2.25.1-py3-none-any.whl (31 kB)
# Installing collected packages: spotipy
#   Attempting uninstall: spotipy
#     Found existing installation: spotipy 2.25.0
#     Uninstalling spotipy-2.25.0:
#       Successfully uninstalled spotipy-2.25.0
# Successfully installed spotipy-2.25.1

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
cm = SpotifyClientCredentials(client_id='d71857a0530b4422ac7cf573a01cd68c',client_secret='ca9877d3fd134b2badbce776f899f482')

# %%
sp =spotipy.Spotify(client_credentials_manager = cm)

# %%
playlist_link = "https://open.spotify.com/playlist/37i9dQZF1DX14CbVHtvHRB"

# %%
playlist_URI = playlist_link.split('/')[-1].split('?')[0]
playlist_URI='6VOedaf3eNWDOVpa9Qdlvg'
playlist_URI
# Out:
# '6VOedaf3eNWDOVpa9Qdlvg'

# %%
data = sp.playlist_tracks(playlist_URI)

# %%
import json
json_data = json.dumps(data)

# %%
json_data
# Out:
# '{"href": "https://api.spotify.com/v1/playlists/6VOedaf3eNWDOVpa9Qdlvg/tracks?offset=0&limit=100&additional_types=track", "items": [{"added_at": "2025-03-07T07:47:46Z", "added_by": {"external_urls": {"spotify": "https://open.spotify.com/user/31rzz7jr6t3e3mqgitwppkmfg2ve"}, "href": "https://api.spotify.com/v1/users/31rzz7jr6t3e3mqgitwppkmfg2ve", "id": "31rzz7jr6t3e3mqgitwppkmfg2ve", "type": "user", "uri": "spotify:user:31rzz7jr6t3e3mqgitwppkmfg2ve"}, "is_local": false, "primary_color": null, "track": {"preview_url": null, "available_markets": ["AR", "AU", "AT", "BE", "BO", "BR", "BG", "CA", "CL", "CO", "CR", "CY", "CZ", "DK", "DO", "DE", "EC", "EE", "SV", "FI", "FR", "GR", "GT", "HN", "HK", "HU", "IS", "IE", "IT", "LV", "LT", "LU", "MY", "MT", "MX", "NL", "NZ", "NI", "NO", "PA", "PY", "PE", "PH", "PL", "PT", "SG", "SK", "ES", "SE", "CH", "TW", "TR", "UY", "US", "GB", "AD", "LI", "MC", "ID", "JP", "TH", "VN", "RO", "IL", "ZA", "SA", "AE", "BH", "QA", "OM", "KW", "EG", "MA", "DZ", "TN", "LB", "JO", "PS", "IN", "BY", "KZ", "MD", "UA", "AL", "BA", "HR", "ME", "MK", "RS", "SI", "KR", "BD", "PK", "LK", "GH", "KE", "NG", "TZ", "UG", "AG", "AM", "BS", "BB", "BZ", "BT", "BW", "BF", "CV", "CW", "DM", "FJ", "GM", "GE", "GD", "GW", "GY", "HT", "JM", "KI", "LS", "LR", "MW", "MV", "ML", "MH", "FM", "NA", "NR", "NE", "PW", "PG", "PR", "WS", "SM", "ST", "SN", "SC", "SL", "SB", "KN", "LC", "VC", "SR", "TL", "TO", "TT", "TV", "VU", "AZ", "BN", "BI", "KH", "CM", "TD", "KM", "GQ", "SZ", "GA", "GN", "KG", "LA", "MO", "MR", "MN", "NP", "RW", "TG", "UZ", "ZW", "BJ", "MG", "MU", "MZ", "AO", "CI", "DJ", "ZM", "CD", "CG", "IQ", "LY", "TJ", "VE", "ET", "XK"], "explicit": false, "type": "track", "episode": false, "track": true, "album": {"available_markets": ["AR", "AU", "AT", "BE", "BO", "BR", "BG", "CA", "CL", "CO", "CR", "CY", "CZ", "DK", "DO", "DE", "EC", "EE", "SV", "FI", "FR", "GR", "GT", "HN", "HK", "HU", "IS", "IE", "IT", "LV", "LT", "LU", "MY", "MT", "MX", "NL", "NZ", "NI", "NO", "PA", "PY", "PE", "PH", "PL", "PT", "SG", "SK", "ES", "SE", "CH", "TW", "TR", "UY", "US", "GB", "AD", "LI", "MC", "ID", "JP", "TH", "VN", "RO", "IL", "ZA", "SA", "AE", "BH", "QA", "OM", "KW", "EG", "MA", "DZ", "TN", "LB", "JO", "PS", "IN", "BY", "KZ", "MD", "UA", "AL", "BA", "HR", "ME", "MK", "RS", "SI", "KR", "BD", "PK", "LK", "GH", "KE", "NG", "TZ", "UG", "AG", "AM", "BS", "BB", "BZ", "BT", "BW", "BF", "CV", "CW", "DM", "FJ", "GM", "GE", "GD", "GW", "GY", "HT", "JM", "KI", "LS", "LR", "MW", "MV", "ML", "MH", "FM", "NA", "NR", "NE", "PW", "PG", "PR", "WS", "SM", "ST", "SN", "SC", "SL", "SB", "KN", "LC", "VC", "SR", "TL", "TO", "TT", "TV", "VU", "AZ", "BN", "BI", "KH", "CM", "TD", "KM", "GQ", "SZ", "GA", "GN", "KG", "LA", "MO", "MR", "MN", "NP", "RW", "TG", "UZ", "ZW", "BJ", "MG", "MU", "MZ", "AO", "CI", "DJ", "ZM", "CD", "CG", "IQ", "LY", "TJ", "VE", "ET", "XK"], "type": "album", "album_type": "single", "href": "https://api.spotify.com/v1/albums/06a7H7nusNMvM7yL8m3fy1", "id": "06a7H7nusNMvM7yL8m3fy1", "images": [{"height": 640, "url": "https://i.scdn.co/image/ab67616d0000b273bb7e0eb64fae8dbd5b9d2a12", "width": 640}, {"height": 300, "url": "https://i.scdn.co/image/ab67616d00001e02bb7e0eb64fae8dbd5b9d2a12", "width": 300}, {"height": 64, "url": "https://i.scdn.co/image/ab67616d00004851bb7e0eb64fae8dbd5b9d2a12", "width": 64}], "name": "AURA", "release_date": "2024-07-12", "release_date_precision": "day", "uri": "spotify:album:06a7H7nusNMvM7yL8m3fy1", "artists": [{"external_urls": {"spotify": "https://open.spotify.com/artist/1Sdc6ySbIvzO0X9vbyHzWm"}, "href": "https://api.spotify.com/v1/artists/1Sdc6ySbIvzO0X9vbyHzWm", "id": "1Sdc6ySbIvzO0X9vbyHzWm", "name": "Ogryzek", "type": "artist", "uri": "spotify:artist:1Sdc6ySbIvzO0X9vbyHzWm"}], "external_urls": {"spotify": "https://open.spotify.com/album/06a7H7nusNMvM7yL8m3fy1"}, "total_tracks": 3}, "artists": [{"external_urls": {"spotify": "https://open.spotify.com/artist/1Sdc6ySbIvzO0X9vbyHzWm"}, "href": "https://api.spotify.com/v1/ ...

# %%
all_info = data['items']
all_info[0]['track']['album']['id']
# Out:
# '06a7H7nusNMvM7yL8m3fy1'

# %%
all_info[0]['track']['album']['name']
# Out:
# 'AURA'

# %%
all_info[1]['track']['album']['name']
# Out:
# 'FUNK UNIVERSO'

# %%
all_info[0]['track']['album']
# Out:
# {'available_markets': ['AR',
#   'AU',
#   'AT',
#   'BE',
#   'BO',
#   'BR',
#   'BG',
#   'CA',
#   'CL',
#   'CO',
#   'CR',
#   'CY',
#   'CZ',
#   'DK',
#   'DO',
#   'DE',
#   'EC',
#   'EE',
#   'SV',
#   'FI',
#   'FR',
#   'GR',
#   'GT',
#   'HN',
#   'HK',
#   'HU',
#   'IS',
#   'IE',
#   'IT',
#   'LV',
#   'LT',
#   'LU',
#   'MY',
#   'MT',
#   'MX',
#   'NL',
#   'NZ',
#   'NI',
#   'NO',
#   'PA',
#   'PY',
#   'PE',
#   'PH',
#   'PL',
#   'PT',
#   'SG',
#   'SK',
#   'ES',
#   'SE',
#   'CH',
#   'TW',
#   'TR',
#   'UY',
#   'US',
#   'GB',
#   'AD',
#   'LI',
#   'MC',
#   'ID',
#   'JP',
#   'TH',
#   'VN',
#   'RO',
#   'IL',
#   'ZA',
#   'SA',
#   'AE',
#   'BH',
#   'QA',
#   'OM',
#   'KW',
#   'EG',
#   'MA',
#   'DZ',
#   'TN',
#   'LB',
#   'JO',
#   'PS',
#   'IN',
#   'BY',
#   'KZ',
#   'MD',
#   'UA',
#   'AL',
#   'BA',
#   'HR',
#   'ME',
#   'MK',
#   'RS',
#   'SI',
#   'KR',
#   'BD',
#   'PK',
#   'LK',
#   'GH',
#   'KE',
#   'NG',
#   'TZ',
#   'UG',
#   'AG',
#   'AM',
#   'BS',
#   'BB',
#   'BZ',
#   'BT',
#   'BW',
#   'BF',
#   'CV',
#   'CW',
#   'DM',
#   'FJ',
#   'GM',
#   'GE',
#   'GD',
#   'GW',
#   'GY',
#   'HT',
#   'JM',
#   'KI',
#   'LS',
#   'LR',
#   'MW',
#   'MV',
#   'ML',
#   'MH',
#   'FM',
#   'NA',
#   'NR',
#   'NE',
#   'PW',
#   'PG',
#   'PR',
#   'WS',
#   'SM',
#   'ST',
#   'SN',
#   'SC',
#   'SL',
#   'SB',
#   'KN',
#   'LC',
#   'VC',
#   'SR',
#   'TL',
#   'TO',
#   'TT',
#   'TV',
#   'VU',
#   'AZ',
#   'BN',
#   'BI',
#   'KH',
#   'CM',
#   'TD',
#   'KM',
#   'GQ',
#   'SZ',
#   'GA',
#   'GN',
#   'KG',
#   'LA',
#   'MO',
#   'MR',
#   'MN',
#   'NP',
#   'RW',
#   'TG',
#   'UZ',
#   'ZW',
#   'BJ',
#   'MG',
#   'MU',
#   'MZ',
#   'AO',
#   'CI',
#   'DJ',
#   'ZM',
#   'CD',
#   'CG',
#   'IQ',
#   'LY',
#   'TJ',
#   'VE',
#   'ET',
#   'XK'],
#  'type': 'album',
#  'album_type': 'single',
#  'href': 'https://api.spotify.com/v1/albums/06a7H7nusNMvM7yL8m3fy1',
#  'id': '06a7H7nusNMvM7yL8m3fy1',
#  'images': [{'height': 640,
#    'url': 'https://i.scdn.co/image/ab67616d0000b273bb7e0eb64fae8dbd5b9d2a12',
#    'width': 640},
#   {'height': 300,
#    'url': 'https://i.scdn.co/image/ab67616d00001e02bb7e0eb64fae8dbd5b9d2a12',
#    'width': 300},
#   {'height': 64,
#    'url': 'https://i.scdn.co/image/ab67616d00004851bb7e0eb64fae8dbd5b9d2a12',
#    'width': 64}],
#  'name': 'AURA',
#  'release_date': '2024-07-12',
#  'release_date_precision': 'day',
#  'uri': 'spotify:album:06a7H7nusNMvM7yL8m3fy1',
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Sdc6ySbIvzO0X9vbyHzWm'},
#    'href': 'https://api.spotify.com/v1/artists/1Sdc6ySbIvzO0X9vbyHzWm',
#    'id': '1Sdc6ySbIvzO0X9vbyHzWm',
#    'name': 'Ogryzek',
#    'type': 'artist',
#    'uri': 'spotify:artist:1Sdc6ySbIvzO0X9vbyHzWm'}],
#  'external_urls': {'spotify': 'https://open.spotify.com/album/06a7H7nusNMvM7yL8m3fy1'},
#  'total_tracks': 3}

# %%
all_info[0]['track']['album']['artists'][0]['name']
# Out:
# 'Ogryzek'

# %%
import pandas as pd

# %%
#album_id = []
#album_name = []
#artists_name = []
album_info = []
for item in range(0, len(all_info)):
    album_id = all_info[item]['track']['album']['id']
    album_name = all_info[item]['track']['album']['name']
    artists_name = all_info[item]['track']['album']['artists'][0]['name']
    album_dict = {'album_id':album_id, 'album_name': album_name, 'artists_name': artists_name}
    album_info.append(album_dict)
    item += 1

# %%
album_info
# Out:
# [{'album_id': '06a7H7nusNMvM7yL8m3fy1',
#   'album_name': 'AURA',
#   'artists_name': 'Ogryzek'},
#  {'album_id': '1kmsUHDC0n611meNgzRkuw',
#   'album_name': 'FUNK UNIVERSO',
#   'artists_name': 'Irokz'},
#  {'album_id': '4FRxgE6LA2UGJ5yz8diaI9',
#   'album_name': 'FUNKED UP',
#   'artists_name': 'xxanteria'},
#  {'album_id': '3tSeUNn7yOQPEex7jwS9Bf',
#   'album_name': 'GLORY',
#   'artists_name': 'Ogryzek'},
#  {'album_id': '6YLJD87ZAaFBziGObBIcOW',
#   'album_name': 'EMPIRE',
#   'artists_name': 'Ogryzek'},
#  {'album_id': '6xUYw5goKIoyJQi9C27UBy',
#   'album_name': 'NUNCA MUDA?',
#   'artists_name': 'Scythermane'},
#  {'album_id': '4s7LxMlh6RxgdMhldfMe8u',
#   'album_name': 'Funk de Beleza',
#   'artists_name': 'Nateki'},
#  {'album_id': '6Zd0Hg3HKVH7xhBPgESQy1',
#   'album_name': 'FUNK DO BOUNCE (Slowed)',
#   'artists_name': 'Ariis'},
#  {'album_id': '1dNr9lYDxO0pyG6poLIVWA',
#   'album_name': 'hypnotic',
#   'artists_name': 'isq'},
#  {'album_id': '1QFKbF3Oot9Ad1NnRCAG32',
#   'album_name': 'X-SLIDE',
#   'artists_name': '2KE'},
#  {'album_id': '4QmDrxVGw99LUJOubfPJz9',
#   'album_name': 'SPOOKY',
#   'artists_name': 'fennecxx'},
#  {'album_id': '51F5iHYpECc8dd9Wjqv15o',
#   'album_name': 'Eu Sento Gabu!',
#   'artists_name': 'PXLWYSE'},
#  {'album_id': '1qlnjo9SZtK01FqDyjv6nM',
#   'album_name': 'EI DO SENSACIO!',
#   'artists_name': 'princce'},
#  {'album_id': '6dNugoBYWvUDQDtLurImhw',
#   'album_name': 'X-TALI',
#   'artists_name': 'MXCCREE'},
#  {'album_id': '5rDznSixlUXNxJySfWQNb7',
#   'album_name': 'REI DO BRASIL',
#   'artists_name': 'Seek'},
#  {'album_id': '6jQlknQwPszOU2pYBkNmO5',
#   'album_name': 'AUTOMOTIVO PA PA PAPAI',
#   'artists_name': 'DJ RIO'},
#  {'album_id': '6s28IiIJ7ElbJfTPn03D6Y',
#   'album_name': 'THOMAS',
#   'artists_name': 'ZWE1HVNDXR'},
#  {'album_id': '1vQpZhp0nRdlUT4m2cgV4k',
#   'album_name': 'Mexican Phonk Eki',
#   'artists_name': 'NUEKI'},
#  {'album_id': '3I0PQFWT0lGD5zWcGHwbRW',
#   'album_name': 'PLANETA DESCONHECIDO',
#   'artists_name': 'DJ NK3'},
#  {'album_id': '1XFONq6J523aOBZDsjtCW8',
#   'album_name': 'Louca Encubada',
#   'artists_name': 'Dj Samir'},
#  {'album_id': '0FNQKStah5NuLZu0Npw17w',
#   'album_name': 'A-What',
#   'artists_name': 'RELYCT'},
#  {'album_id': '3Ar02fcnzPDg1xvy05pWff',
#   'album_name': 'Se Paciente Funk',
#   'artists_name': 'RD12'},
#  {'album_id': '2i9lYE2CWNBLmDiXwJ884n',
#   'album_name': 'EL QUE LA DEBE FUNK',
#   'artists_name': 'FR3ST'},
#  {'album_id': '6mfljhxeSViWr01HscxHjS',
#   'album_name': 'BAD PARENTING FUNK V2',
#   'artists_name': 'Sayfalse'},
#  {'album_id': '5n9EF7hP2GRMiklzLpPY0E',
#   'album_name': 'AVANGARD (Slowed)',
#   'artists_name': 'LONOWN'},
#  {'album_id': '3ra1kh1AmwAFm1jg9dwONE',
#   'album_name': 'JOGO DE TOLOS',
#   'artists_name': 'Scythermane'},
#  {'album_id': '1Wr2LyF0JSHHPv9nGXgFTN',
#   'album_name': 'O Melhor no Que Faz 3.0 [Slowed]',
#   'artists_name': 'DJ BRYAN 7'},
#  {'album_id': '7JslfZtjZ430btdARyxLQ4',
#   'album_name': 'PYTHON FUNK',
#   'artists_name': 'RD12'},
#  {'album_id': '2Osz2h7ZjKHOZh5grL7o6G',
#   'album_name': 'BAIXO',
#   'artists_name': 'xxanteria'},
#  {'album_id': '7EWDvEG6vKIjTBk3rGMtP0',
#   'album_name': 'BRODYAGA FUNK',
#   'artists_name': 'Eternxlkz'},
#  {'album_id': '0cpfgDzjHZuYfiBc7jPsn6',
#   'album_name': 'Funk of Galáctico',
#   'artists_name': 'SXID'},
#  {'album_id': '1k9oQsBjwIhc4vF32zxvY5',
#   'album_name': 'NEXT!',
#   'artists_name': 'NCTS'},
#  {'album_id': '5eRHyCycBt78BNaa8vR4Si',
#   'album_name': 'FRESH',
#   'artists_name': 'NXVAMANE'},
#  {'album_id': '2RhX80u97LacDUbFoSLT5W',
#   'album_name': 'MONTAGEM BRAVO',
#   'artists_name': 'ZXKAI'},
#  {'album_id': '27XmqsKeLyr5jDURAordcd',
#   'album_name': 'TUCA DONKA',
#   'artists_name': 'CURSEDEVIL'},
#  {'album_id': '6DptPhwLku8xvWBodULnC6',
#   'album_name': 'Orquestra Maldita',
#   'artists_name': 'TRASHXRL'},
#  {'album_id': '1ILssfrknV8cQv5QvwBGUY',
#   'album_name': 'DNA',
#   'artists_name': 'LXNGVX'},
#  {'album_id': '6tf2ziKDZQJinItJi99wBW',
#   'album_name': 'SPACE!',
#   'artists_name': 'NAOMI'},
#  {'album_id': '3BsuqyYCV0DYIBrDi1SKwQ',
#   'album_name': 'Sequência da Dz7',
#   'artists_name': 'TRASHXRL'},
#  {'album_id': '2EuOCirl08WxbRY2cfj4H5',
#   'album_name': 'Life in Rio',
#   'artists_name': 'Slowboy'},
#  {'album_id': '7cNqBJdXx8dgoXegihUPVN',
#   'album_name': 'Turu R9',
#   'artists_name': 'DJ Ikeraus'},
#  {'album_id': '3Iw0jAPzwgmuqSIWQa9i8W',
#   'album_name': 'FUNK INFERNAL',
#   'artists_name': 'DYGO'},
#  {'album_id': '6la9ubAAPlhP8eylFPuLlC',
#   'album_name': 'Montagem Sonic Ritmado 1.0 (Slowed)',
#   'artists_name': 'TOKYOPHILE'},
#  {'album_id': '1R1KJCX1oc3xqSbABo2Wpn',
#   'album_name': 'Montagem Injuriosum Retines (Slowed)',
#   'artists_name': 'DJ JEEAN 011'},
#  {'album_id': '1mEN4vjqXeZN9FmNzFLCBf',
#   'album_name': 'AUTOMOTIVO DA TURBULENCIA',
#   'artists_name': 'Various Artists'},
#  {'album_id': '2bqWrlHmNh4M41xOr0p7iN',
#   'album_name': 'Funk Secreto (Ultra Slowed)',
#   'artists_name': 'h6itam'},
#  {'album_id': '3HEJNpi4OtYpYQlGy2anVB',
#   'album_name': 'void',
#   'artists_name': 'isq'},
#  {'album_id': '74uo4Lv0VMyxdOjlf40y1T',
#   'album_name': 'FUNK ESTRANHO (SUPER SLOWED)',
#   'artists_name': 'Astora'},
#  {'album_id': '5jXbkZ8fgtvq5OufR9LJz4',
#   'album_name': 'BLUE HORIZON FUNK',
#   'artists_name': 'NXGHT!'},
#  {'album_id': '7hNzImuUou9dBftesPXcAt',
#   'album_name': 'BLAH',
#   'artists_name': 'Hexora'},
#  {'album_id': '1Idktx9vdSSkm1yxABycnf',
#   'album_name': 'DON`T STOP',
#   'artists_name': 'GLXXMSTRIDER'},
#  {'album_id': '3xCc8FxQsm6AE7ZWJ7h5sx',
#   'album_name': 'SLAY!',
#   'artists_name': 'Eternxlkz'},
#  {'album_id': '5rl2NDQDv9VpZLoEFOaYNg',
#   'album_name': 'MONTAGEM INVASÃO',
#   'artists_name': 'ARXMANE'},
#  {'album_id': '6Uu8uYmykgF00mPNl6pa91',
#   'album_name': 'DECEITFUL',
#   'artists_name': '509 $icario'},
#  {'album_id': '09xRsRc7pX399wCGElOfMT',
#   'album_name': 'BRUXO FANTASMA',
#   'artists_name': 'LXNGVX'},
#  {'album_id': '5tod76GzFMGREffztRiLyJ',
#   'album_name': 'Montagem Lunar Celestia 1.0 (SLOWED)',
#   'artists_name': 'TOKYOPHILE'},
#  {'album_id': '5eEfzNcFaXPsBXJzkPiD3S',
#   'album_name': 'Beeper Funk (Slowed)',
#   'artists_name': 'DJ Paulinho Mondi Da Baixa Baviera'},
#  {'album_id': '6PZBt4XZvd1ElHAHG31J1j',
#   'album_name': 'FUNK DO BALKAN',
#   'artists_name': '$werve'},
#  {'album_id': '05EQpLFKhJ1m4YElm4zDHr',
#   'album_name': 'Ela Vira Mortal',
#   'artists_name': 'DJ Vilão DS'},
#  {'album_id': '2R1AMmWGUa5IJYAdejtajq',
#   'album_name': 'O Melhor no Que Faz 3.0',
#   'artists_name': 'DJ BRYAN 7'},
#  {'album_id': '5Ide1hRSwzUYUnTQhq6CBv',
#   'album_name': 'Death Is No More',
#   'artists_name': 'BLESSED MANE'},
#  {'album_id': '4Fpr7mZ709qg0Iu1ESYNwz',
#   'album_name': 'SEQUÊNCIA MALÉFICA 1.0',
#   'artists_name': 'RXPOSO99'},
#  {'album_id': '7Bc7xEWvkW01bvq5jAhCQS',
#   'album_name': 'YUM YUM',
#   'artists_name': 'LXNGVX'},
#  {'album_id': '2DNOGCn0szoh9f3rAnhF7b',
#   'album_name': 'BAD PARENTING FUNK',
#   'artists_name': 'DJ CEREJASS'},
#  {'album_id': '5hUTWbVLPE7Vo9KtS06U15',
#   'album_name': 'Cuando se te moja la tarea 2',
#   'artists_name': 'LDRR'},
#  {'album_id': '4ibsk1iPM7xDpJkNXREmsl',
#   'album_name': 'MANDA BALA',
#   'artists_name': 'Ariis'},
#  {'album_id': '4hBpayDWGOGsgnwFY8qm3G',
#   'album_name': 'FUNK OSCURO',
#   'artists_name': 'h6itam'},
#  {'album_id': '5NJDkJdeVRTLpOJalNfb95',
#   'album_name': 'Montagem Bionica Espectral 2 (Slowed + Reverb)',
#   'artists_name': 'DJ OLIVEIRA ORIGINAL'},
#  {'album_id': '7lolzbhq4moSJPfFpdosl5',
#   'album_name': 'RISADA CHUCK 01',
#   'artists_name': '-Prey'},
#  {'album_id': '47VSbmVnuMFiaFv3ZiK0Ee',
#   'album_name': 'ACIDO',
#   'artists_name': 'UdieNnx'},
#  {'album_id': '5J00ADHG1jlJiLjQDPURVh',
#   'album_name': 'ICEWHORE!',
#   'artists_name': 'Lumi Athena'},
#  {'album_id': '28N1pcdMLhrEajfJKkBkl1',
#   'album_name': 'MONTAGEM DIAMANTE ROSA',
#   'artists_name': 'vtze archive'},
#  {'album_id': '7DGsEVuwdKBKrzDx8fzEKn',
#   'album_name': 'MTG - VINGANÇA',
#   'artists_name': 'DJ FKU'},
#  {'album_id': '6h4Lw0QisEuuAwmnMQvbse',
#   'album_name': 'VAPO NO SETOR',
#   'artists_name': 'DJ ANXVAR'},
#  {'album_id': '4cfBuRZw1az5lIdTYxuOPq',
#   'album_name': 'BIBI PHONK BR',
#   'artists_name': 'Bibi Babydoll'},
#  {'album_id': '5mGMCvuF70Alfy0FXg3Sn7',
#   'album_name': 'x-tudo',
#   'artists_name': 'slxughter'},
#  {'album_id': '0VnjSeajDjzh2mRdWePGhN',
#   'album_name': 'AREAMATE MIZ',
#   'artists_name': 'Anar'},
#  {'album_id': '4J0FEQtbjPH1DA60p6bKe9',
#   'album_name': 'YUMMI',
#   'artists_name': 'LXNGVX'},
#  {'album_id': '6tuTOSJX2SjH8JBsh5uM30',
#   'album_name': 'WHINE IN BRAZIL FUNK',
#   'artists_name': 'Ichiss'},
#  {'album_id': '58Uel2jPuFAf4bRiWHLYVz',
#   'album_name': 'MONTAGEM VOZES PROFUNDAS (TikTok Version)',
#   'artists_name': 'DJ MAXZZ'},
#  {'album_id': '4sWmzhpogE4nLa1f2q9Ke0',
#   'album_name': 'Slide da Treme Melódica v2',
#   'artists_name': 'DJ FNK'},
#  {'album_id': '5T9u88WBOgCsGk3GT30Z3r',
#   'album_name': 'Bero 02',
#   'artists_name': 'Anar'},
#  {'album_id': '3D2j7JQjj9Kjc8sOfikmV6',
#   'album_name': 'Montagem Melodia Explosiva',
#   'artists_name': 'Vermillion'}]

# %%
df = pd.DataFrame(album_info)

# %%
df
# Out:
#                   album_id                                 album_name  \
# 0   06a7H7nusNMvM7yL8m3fy1                                       AURA
# 1   1kmsUHDC0n611meNgzRkuw                              FUNK UNIVERSO
# 2   4FRxgE6LA2UGJ5yz8diaI9                                  FUNKED UP
# 3   3tSeUNn7yOQPEex7jwS9Bf                                      GLORY
# 4   6YLJD87ZAaFBziGObBIcOW                                     EMPIRE
# ..                     ...                                        ...
# 78  6tuTOSJX2SjH8JBsh5uM30                       WHINE IN BRAZIL FUNK
# 79  58Uel2jPuFAf4bRiWHLYVz  MONTAGEM VOZES PROFUNDAS (TikTok Version)
# 80  4sWmzhpogE4nLa1f2q9Ke0                 Slide da Treme Melódica v2
# 81  5T9u88WBOgCsGk3GT30Z3r                                    Bero 02
# 82  3D2j7JQjj9Kjc8sOfikmV6                 Montagem Melodia Explosiva
#
#    artists_name
# 0       Ogryzek
# 1         Irokz
# 2     xxanteria
# 3       Ogryzek
# 4       Ogryzek
# ..          ...
# 78       Ichiss
# 79     DJ MAXZZ
# 80       DJ FNK
# 81         Anar
# 82   Vermillion
#
# [83 rows x 3 columns]

# %%
all_info[0]['track']['id'] #album id
# Out:
# '2TNv2GxMpIO8AyPiD7TLxj'

# %%
all_info[0]['track']['href'] #album url
# Out:
# 'https://api.spotify.com/v1/tracks/2TNv2GxMpIO8AyPiD7TLxj'

# %%
all_info[0]['track']['album']['external_urls']
# Out:
# {'spotify': 'https://open.spotify.com/album/06a7H7nusNMvM7yL8m3fy1'}

# %%
album_infoall_info[0]['track']['album']['total_tracks']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 album_infoall_info[0]['track']['album']['total_tracks']
#
# NameError: name 'album_infoall_info' is not defined

# %%
album_info = []
for item in range(0, len(all_info)):
    album_id = all_info[item]['track']['album']['id']
    album_name = all_info[item]['track']['album']['name']
    release_date = all_info[item]['track']['album']['release_date']
    total_tracks = all_info[item]['track']['album']['total_tracks']
    url = all_info[item]['track']['album']['external_urls']['spotify']
    album_dict = {'album_id':album_id, 'album_name':album_name, 'release_date':release_date, 'total_tracks':total_tracks, 'url':url}
    album_info.append(album_dict)
    item += 1

# %%
artist_info = []
for item in range(0, len(all_info)):
    artist_id = all_info[item]['track']['artists'][0]['id']
    artist_name = all_info[item]['track']['artists'][0]['name']
    external_url = all_info[item]['track']['artists'][0]['external_urls']['spotify']
    artist_dict = {'artist_id':artist_id, 'artist_name':artist_name, 'external_url':external_url}
    artist_info.append(artist_dict)
    item += 1

# %%
song_info = []
for item in range(0, len(all_info)):
    song_id = all_info[item]['track']['id']
    song_name = all_info[item]['track']['name']
    song_duration = all_info[item]['track']['duration_ms']
    song_url = all_info[item]['track']['href']
    song_popularity = all_info[item]['track']['popularity']
    song_added = all_info[item]['added_at']
    album_id = all_info[item]['track']['album']['id']
    artist_id = all_info[item]['track']['artists'][0]['id']
    song_dict = {'song_id':song_id, 'song_name':song_name, 'song_duration':song_duration,'song_url':song_url,'song_popularity':song_popularity,'song_added':song_added, 'album_id':album_id, 'artist_id':artist_id}
    song_info.append(song_dict)
    item += 1

# %%
album_df = pd.DataFrame.from_dict(album_info)

# %%
album_info
# Out:
# [{'album_id': '06a7H7nusNMvM7yL8m3fy1',
#   'album_name': 'AURA',
#   'release_date': '2024-07-12',
#   'total_tracks': 3,
#   'url': 'https://open.spotify.com/album/06a7H7nusNMvM7yL8m3fy1'},
#  {'album_id': '1kmsUHDC0n611meNgzRkuw',
#   'album_name': 'FUNK UNIVERSO',
#   'release_date': '2024-07-03',
#   'total_tracks': 4,
#   'url': 'https://open.spotify.com/album/1kmsUHDC0n611meNgzRkuw'},
#  {'album_id': '4FRxgE6LA2UGJ5yz8diaI9',
#   'album_name': 'FUNKED UP',
#   'release_date': '2024-01-19',
#   'total_tracks': 3,
#   'url': 'https://open.spotify.com/album/4FRxgE6LA2UGJ5yz8diaI9'},
#  {'album_id': '3tSeUNn7yOQPEex7jwS9Bf',
#   'album_name': 'GLORY',
#   'release_date': '2024-05-24',
#   'total_tracks': 3,
#   'url': 'https://open.spotify.com/album/3tSeUNn7yOQPEex7jwS9Bf'},
#  {'album_id': '6YLJD87ZAaFBziGObBIcOW',
#   'album_name': 'EMPIRE',
#   'release_date': '2024-08-02',
#   'total_tracks': 3,
#   'url': 'https://open.spotify.com/album/6YLJD87ZAaFBziGObBIcOW'},
#  {'album_id': '6xUYw5goKIoyJQi9C27UBy',
#   'album_name': 'NUNCA MUDA?',
#   'release_date': '2025-01-09',
#   'total_tracks': 6,
#   'url': 'https://open.spotify.com/album/6xUYw5goKIoyJQi9C27UBy'},
#  {'album_id': '4s7LxMlh6RxgdMhldfMe8u',
#   'album_name': 'Funk de Beleza',
#   'release_date': '2024-10-04',
#   'total_tracks': 3,
#   'url': 'https://open.spotify.com/album/4s7LxMlh6RxgdMhldfMe8u'},
#  {'album_id': '6Zd0Hg3HKVH7xhBPgESQy1',
#   'album_name': 'FUNK DO BOUNCE (Slowed)',
#   'release_date': '2024-08-30',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/6Zd0Hg3HKVH7xhBPgESQy1'},
#  {'album_id': '1dNr9lYDxO0pyG6poLIVWA',
#   'album_name': 'hypnotic',
#   'release_date': '2024-05-31',
#   'total_tracks': 3,
#   'url': 'https://open.spotify.com/album/1dNr9lYDxO0pyG6poLIVWA'},
#  {'album_id': '1QFKbF3Oot9Ad1NnRCAG32',
#   'album_name': 'X-SLIDE',
#   'release_date': '2024-05-10',
#   'total_tracks': 4,
#   'url': 'https://open.spotify.com/album/1QFKbF3Oot9Ad1NnRCAG32'},
#  {'album_id': '4QmDrxVGw99LUJOubfPJz9',
#   'album_name': 'SPOOKY',
#   'release_date': '2024-10-24',
#   'total_tracks': 4,
#   'url': 'https://open.spotify.com/album/4QmDrxVGw99LUJOubfPJz9'},
#  {'album_id': '51F5iHYpECc8dd9Wjqv15o',
#   'album_name': 'Eu Sento Gabu!',
#   'release_date': '2024-04-19',
#   'total_tracks': 4,
#   'url': 'https://open.spotify.com/album/51F5iHYpECc8dd9Wjqv15o'},
#  {'album_id': '1qlnjo9SZtK01FqDyjv6nM',
#   'album_name': 'EI DO SENSACIO!',
#   'release_date': '2024-07-29',
#   'total_tracks': 4,
#   'url': 'https://open.spotify.com/album/1qlnjo9SZtK01FqDyjv6nM'},
#  {'album_id': '6dNugoBYWvUDQDtLurImhw',
#   'album_name': 'X-TALI',
#   'release_date': '2024-08-23',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/6dNugoBYWvUDQDtLurImhw'},
#  {'album_id': '5rDznSixlUXNxJySfWQNb7',
#   'album_name': 'REI DO BRASIL',
#   'release_date': '2023-06-02',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/5rDznSixlUXNxJySfWQNb7'},
#  {'album_id': '6jQlknQwPszOU2pYBkNmO5',
#   'album_name': 'AUTOMOTIVO PA PA PAPAI',
#   'release_date': '2024-04-29',
#   'total_tracks': 2,
#   'url': 'https://open.spotify.com/album/6jQlknQwPszOU2pYBkNmO5'},
#  {'album_id': '6s28IiIJ7ElbJfTPn03D6Y',
#   'album_name': 'THOMAS',
#   'release_date': '2024-04-12',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/6s28IiIJ7ElbJfTPn03D6Y'},
#  {'album_id': '1vQpZhp0nRdlUT4m2cgV4k',
#   'album_name': 'Mexican Phonk Eki',
#   'release_date': '2023-06-23',
#   'total_tracks': 3,
#   'url': 'https://open.spotify.com/album/1vQpZhp0nRdlUT4m2cgV4k'},
#  {'album_id': '3I0PQFWT0lGD5zWcGHwbRW',
#   'album_name': 'PLANETA DESCONHECIDO',
#   'release_date': '2024-01-26',
#   'total_tracks': 3,
#   'url': 'https://open.spotify.com/album/3I0PQFWT0lGD5zWcGHwbRW'},
#  {'album_id': '1XFONq6J523aOBZDsjtCW8',
#   'album_name': 'Louca Encubada',
#   'release_date': '2023-10-13',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/1XFONq6J523aOBZDsjtCW8'},
#  {'album_id': '0FNQKStah5NuLZu0Npw17w',
#   'album_name': 'A-What',
#   'release_date': '2024-06-21',
#   'total_tracks': 3,
#   'url': 'https://open.spotify.com/album/0FNQKStah5NuLZu0Npw17w'},
#  {'album_id': '3Ar02fcnzPDg1xvy05pWff',
#   'album_name': 'Se Paciente Funk',
#   'release_date': '2024-07-26',
#   'total_tracks': 3,
#   'url': 'https://open.spotify.com/album/3Ar02fcnzPDg1xvy05pWff'},
#  {'album_id': '2i9lYE2CWNBLmDiXwJ884n',
#   'album_name': 'EL QUE LA DEBE FUNK',
#   'release_date': '2024-11-06',
#   'total_tracks': 4,
#   'url': 'https://open.spotify.com/album/2i9lYE2CWNBLmDiXwJ884n'},
#  {'album_id': '6mfljhxeSViWr01HscxHjS',
#   'album_name': 'BAD PARENTING FUNK V2',
#   'release_date': '2024-10-21',
#   'total_tracks': 4,
#   'url': 'https://open.spotify.com/album/6mfljhxeSViWr01HscxHjS'},
#  {'album_id': '5n9EF7hP2GRMiklzLpPY0E',
#   'album_name': 'AVANGARD (Slowed)',
#   'release_date': '2024-08-02',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/5n9EF7hP2GRMiklzLpPY0E'},
#  {'album_id': '3ra1kh1AmwAFm1jg9dwONE',
#   'album_name': 'JOGO DE TOLOS',
#   'release_date': '2024-09-13',
#   'total_tracks': 5,
#   'url': 'https://open.spotify.com/album/3ra1kh1AmwAFm1jg9dwONE'},
#  {'album_id': '1Wr2LyF0JSHHPv9nGXgFTN',
#   'album_name': 'O Melhor no Que Faz 3.0 [Slowed]',
#   'release_date': '2024-07-22',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/1Wr2LyF0JSHHPv9nGXgFTN'},
#  {'album_id': '7JslfZtjZ430btdARyxLQ4',
#   'album_name': 'PYTHON FUNK',
#   'release_date': '2024-08-23',
#   'total_tracks': 4,
#   'url': 'https://open.spotify.com/album/7JslfZtjZ430btdARyxLQ4'},
#  {'album_id': '2Osz2h7ZjKHOZh5grL7o6G',
#   'album_name': 'BAIXO',
#   'release_date': '2023-09-19',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/2Osz2h7ZjKHOZh5grL7o6G'},
#  {'album_id': '7EWDvEG6vKIjTBk3rGMtP0',
#   'album_name': 'BRODYAGA FUNK',
#   'release_date': '2023-11-17',
#   'total_tracks': 4,
#   'url': 'https://open.spotify.com/album/7EWDvEG6vKIjTBk3rGMtP0'},
#  {'album_id': '0cpfgDzjHZuYfiBc7jPsn6',
#   'album_name': 'Funk of Galáctico',
#   'release_date': '2024-04-05',
#   'total_tracks': 3,
#   'url': 'https://open.spotify.com/album/0cpfgDzjHZuYfiBc7jPsn6'},
#  {'album_id': '1k9oQsBjwIhc4vF32zxvY5',
#   'album_name': 'NEXT!',
#   'release_date': '2024-06-07',
#   'total_tracks': 4,
#   'url': 'https://open.spotify.com/album/1k9oQsBjwIhc4vF32zxvY5'},
#  {'album_id': '5eRHyCycBt78BNaa8vR4Si',
#   'album_name': 'FRESH',
#   'release_date': '2023-02-24',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/5eRHyCycBt78BNaa8vR4Si'},
#  {'album_id': '2RhX80u97LacDUbFoSLT5W',
#   'album_name': 'MONTAGEM BRAVO',
#   'release_date': '2024-11-29',
#   'total_tracks': 3,
#   'url': 'https://open.spotify.com/album/2RhX80u97LacDUbFoSLT5W'},
#  {'album_id': '27XmqsKeLyr5jDURAordcd',
#   'album_name': 'TUCA DONKA',
#   'release_date': '2023-07-28',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/27XmqsKeLyr5jDURAordcd'},
#  {'album_id': '6DptPhwLku8xvWBodULnC6',
#   'album_name': 'Orquestra Maldita',
#   'release_date': '2023-06-15',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/6DptPhwLku8xvWBodULnC6'},
#  {'album_id': '1ILssfrknV8cQv5QvwBGUY',
#   'album_name': 'DNA',
#   'release_date': '2023-12-21',
#   'total_tracks': 3,
#   'url': 'https://open.spotify.com/album/1ILssfrknV8cQv5QvwBGUY'},
#  {'album_id': '6tf2ziKDZQJinItJi99wBW',
#   'album_name': 'SPACE!',
#   'release_date': '2024-04-26',
#   'total_tracks': 3,
#   'url': 'https://open.spotify.com/album/6tf2ziKDZQJinItJi99wBW'},
#  {'album_id': '3BsuqyYCV0DYIBrDi1SKwQ',
#   'album_name': 'Sequência da Dz7',
#   'release_date': '2023-05-07',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/3BsuqyYCV0DYIBrDi1SKwQ'},
#  {'album_id': '2EuOCirl08WxbRY2cfj4H5',
#   'album_name': 'Life in Rio',
#   'release_date': '2023-03-17',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/2EuOCirl08WxbRY2cfj4H5'},
#  {'album_id': '7cNqBJdXx8dgoXegihUPVN',
#   'album_name': 'Turu R9',
#   'release_date': '2024-04-01',
#   'total_tracks': 3,
#   'url': 'https://open.spotify.com/album/7cNqBJdXx8dgoXegihUPVN'},
#  {'album_id': '3Iw0jAPzwgmuqSIWQa9i8W',
#   'album_name': 'FUNK INFERNAL',
#   'release_date': '2024-09-27',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/3Iw0jAPzwgmuqSIWQa9i8W'},
#  {'album_id': '6la9ubAAPlhP8eylFPuLlC',
#   'album_name': 'Montagem Sonic Ritmado 1.0 (Slowed)',
#   'release_date': '2024-05-15',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/6la9ubAAPlhP8eylFPuLlC'},
#  {'album_id': '1R1KJCX1oc3xqSbABo2Wpn',
#   'album_name': 'Montagem Injuriosum Retines (Slowed)',
#   'release_date': '2024-08-23',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/1R1KJCX1oc3xqSbABo2Wpn'},
#  {'album_id': '1mEN4vjqXeZN9FmNzFLCBf',
#   'album_name': 'AUTOMOTIVO DA TURBULENCIA',
#   'release_date': '2024-10-08',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/1mEN4vjqXeZN9FmNzFLCBf'},
#  {'album_id': '2bqWrlHmNh4M41xOr0p7iN',
#   'album_name': 'Funk Secreto (Ultra Slowed)',
#   'release_date': '2024-09-09',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/2bqWrlHmNh4M41xOr0p7iN'},
#  {'album_id': '3HEJNpi4OtYpYQlGy2anVB',
#   'album_name': 'void',
#   'release_date': '2024-08-23',
#   'total_tracks': 3,
#   'url': 'https://open.spotify.com/album/3HEJNpi4OtYpYQlGy2anVB'},
#  {'album_id': '74uo4Lv0VMyxdOjlf40y1T',
#   'album_name': 'FUNK ESTRANHO (SUPER SLOWED)',
#   'release_date': '2024-07-30',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/74uo4Lv0VMyxdOjlf40y1T'},
#  {'album_id': '5jXbkZ8fgtvq5OufR9LJz4',
#   'album_name': 'BLUE HORIZON FUNK',
#   'release_date': '2024-11-25',
#   'total_tracks': 5,
#   'url': 'https://open.spotify.com/album/5jXbkZ8fgtvq5OufR9LJz4'},
#  {'album_id': '7hNzImuUou9dBftesPXcAt',
#   'album_name': 'BLAH',
#   'release_date': '2025-02-13',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/7hNzImuUou9dBftesPXcAt'},
#  {'album_id': '1Idktx9vdSSkm1yxABycnf',
#   'album_name': 'DON`T STOP',
#   'release_date': '2024-04-19',
#   'total_tracks': 5,
#   'url': 'https://open.spotify.com/album/1Idktx9vdSSkm1yxABycnf'},
#  {'album_id': '3xCc8FxQsm6AE7ZWJ7h5sx',
#   'album_name': 'SLAY!',
#   'release_date': '2024-03-15',
#   'total_tracks': 4,
#   'url': 'https://open.spotify.com/album/3xCc8FxQsm6AE7ZWJ7h5sx'},
#  {'album_id': '5rl2NDQDv9VpZLoEFOaYNg',
#   'album_name': 'MONTAGEM INVASÃO',
#   'release_date': '2024-03-21',
#   'total_tracks': 3,
#   'url': 'https://open.spotify.com/album/5rl2NDQDv9VpZLoEFOaYNg'},
#  {'album_id': '6Uu8uYmykgF00mPNl6pa91',
#   'album_name': 'DECEITFUL',
#   'release_date': '2025-02-13',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/6Uu8uYmykgF00mPNl6pa91'},
#  {'album_id': '09xRsRc7pX399wCGElOfMT',
#   'album_name': 'BRUXO FANTASMA',
#   'release_date': '2024-08-16',
#   'total_tracks': 4,
#   'url': 'https://open.spotify.com/album/09xRsRc7pX399wCGElOfMT'},
#  {'album_id': '5tod76GzFMGREffztRiLyJ',
#   'album_name': 'Montagem Lunar Celestia 1.0 (SLOWED)',
#   'release_date': '2024-10-14',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/5tod76GzFMGREffztRiLyJ'},
#  {'album_id': '5eEfzNcFaXPsBXJzkPiD3S',
#   'album_name': 'Beeper Funk (Slowed)',
#   'release_date': '2024-08-09',
#   'total_tracks': 2,
#   'url': 'https://open.spotify.com/album/5eEfzNcFaXPsBXJzkPiD3S'},
#  {'album_id': '6PZBt4XZvd1ElHAHG31J1j',
#   'album_name': 'FUNK DO BALKAN',
#   'release_date': '2024-10-18',
#   'total_tracks': 4,
#   'url': 'https://open.spotify.com/album/6PZBt4XZvd1ElHAHG31J1j'},
#  {'album_id': '05EQpLFKhJ1m4YElm4zDHr',
#   'album_name': 'Ela Vira Mortal',
#   'release_date': '2022-08-05',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/05EQpLFKhJ1m4YElm4zDHr'},
#  {'album_id': '2R1AMmWGUa5IJYAdejtajq',
#   'album_name': 'O Melhor no Que Faz 3.0',
#   'release_date': '2024-06-27',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/2R1AMmWGUa5IJYAdejtajq'},
#  {'album_id': '5Ide1hRSwzUYUnTQhq6CBv',
#   'album_name': 'Death Is No More',
#   'release_date': '2021-01-25',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/5Ide1hRSwzUYUnTQhq6CBv'},
#  {'album_id': '4Fpr7mZ709qg0Iu1ESYNwz',
#   'album_name': 'SEQUÊNCIA MALÉFICA 1.0',
#   'release_date': '2024-02-19',
#   'total_tracks': 4,
#   'url': 'https://open.spotify.com/album/4Fpr7mZ709qg0Iu1ESYNwz'},
#  {'album_id': '7Bc7xEWvkW01bvq5jAhCQS',
#   'album_name': 'YUM YUM',
#   'release_date': '2023-06-23',
#   'total_tracks': 3,
#   'url': 'https://open.spotify.com/album/7Bc7xEWvkW01bvq5jAhCQS'},
#  {'album_id': '2DNOGCn0szoh9f3rAnhF7b',
#   'album_name': 'BAD PARENTING FUNK',
#   'release_date': '2024-10-22',
#   'total_tracks': 4,
#   'url': 'https://open.spotify.com/album/2DNOGCn0szoh9f3rAnhF7b'},
#  {'album_id': '5hUTWbVLPE7Vo9KtS06U15',
#   'album_name': 'Cuando se te moja la tarea 2',
#   'release_date': '2024-06-21',
#   'total_tracks': 4,
#   'url': 'https://open.spotify.com/album/5hUTWbVLPE7Vo9KtS06U15'},
#  {'album_id': '4ibsk1iPM7xDpJkNXREmsl',
#   'album_name': 'MANDA BALA',
#   'release_date': '2023-12-08',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/4ibsk1iPM7xDpJkNXREmsl'},
#  {'album_id': '4hBpayDWGOGsgnwFY8qm3G',
#   'album_name': 'FUNK OSCURO',
#   'release_date': '2024-10-24',
#   'total_tracks': 5,
#   'url': 'https://open.spotify.com/album/4hBpayDWGOGsgnwFY8qm3G'},
#  {'album_id': '5NJDkJdeVRTLpOJalNfb95',
#   'album_name': 'Montagem Bionica Espectral 2 (Slowed + Reverb)',
#   'release_date': '2024-07-24',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/5NJDkJdeVRTLpOJalNfb95'},
#  {'album_id': '7lolzbhq4moSJPfFpdosl5',
#   'album_name': 'RISADA CHUCK 01',
#   'release_date': '2024-08-26',
#   'total_tracks': 4,
#   'url': 'https://open.spotify.com/album/7lolzbhq4moSJPfFpdosl5'},
#  {'album_id': '47VSbmVnuMFiaFv3ZiK0Ee',
#   'album_name': 'ACIDO',
#   'release_date': '2024-10-31',
#   'total_tracks': 4,
#   'url': 'https://open.spotify.com/album/47VSbmVnuMFiaFv3ZiK0Ee'},
#  {'album_id': '5J00ADHG1jlJiLjQDPURVh',
#   'album_name': 'ICEWHORE!',
#   'release_date': '2023-03-24',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/5J00ADHG1jlJiLjQDPURVh'},
#  {'album_id': '28N1pcdMLhrEajfJKkBkl1',
#   'album_name': 'MONTAGEM DIAMANTE ROSA',
#   'release_date': '2024-01-09',
#   'total_tracks': 2,
#   'url': 'https://open.spotify.com/album/28N1pcdMLhrEajfJKkBkl1'},
#  {'album_id': '7DGsEVuwdKBKrzDx8fzEKn',
#   'album_name': 'MTG - VINGANÇA',
#   'release_date': '2024-01-26',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/7DGsEVuwdKBKrzDx8fzEKn'},
#  {'album_id': '6h4Lw0QisEuuAwmnMQvbse',
#   'album_name': 'VAPO NO SETOR',
#   'release_date': '2024-08-13',
#   'total_tracks': 5,
#   'url': 'https://open.spotify.com/album/6h4Lw0QisEuuAwmnMQvbse'},
#  {'album_id': '4cfBuRZw1az5lIdTYxuOPq',
#   'album_name': 'BIBI PHONK BR',
#   'release_date': '2023-08-25',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/4cfBuRZw1az5lIdTYxuOPq'},
#  {'album_id': '5mGMCvuF70Alfy0FXg3Sn7',
#   'album_name': 'x-tudo',
#   'release_date': '2024-01-25',
#   'total_tracks': 3,
#   'url': 'https://open.spotify.com/album/5mGMCvuF70Alfy0FXg3Sn7'},
#  {'album_id': '0VnjSeajDjzh2mRdWePGhN',
#   'album_name': 'AREAMATE MIZ',
#   'release_date': '2023-08-28',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/0VnjSeajDjzh2mRdWePGhN'},
#  {'album_id': '4J0FEQtbjPH1DA60p6bKe9',
#   'album_name': 'YUMMI',
#   'release_date': '2023-10-02',
#   'total_tracks': 3,
#   'url': 'https://open.spotify.com/album/4J0FEQtbjPH1DA60p6bKe9'},
#  {'album_id': '6tuTOSJX2SjH8JBsh5uM30',
#   'album_name': 'WHINE IN BRAZIL FUNK',
#   'release_date': '2024-07-09',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/6tuTOSJX2SjH8JBsh5uM30'},
#  {'album_id': '58Uel2jPuFAf4bRiWHLYVz',
#   'album_name': 'MONTAGEM VOZES PROFUNDAS (TikTok Version)',
#   'release_date': '2024-07-12',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/58Uel2jPuFAf4bRiWHLYVz'},
#  {'album_id': '4sWmzhpogE4nLa1f2q9Ke0',
#   'album_name': 'Slide da Treme Melódica v2',
#   'release_date': '2024-05-17',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/4sWmzhpogE4nLa1f2q9Ke0'},
#  {'album_id': '5T9u88WBOgCsGk3GT30Z3r',
#   'album_name': 'Bero 02',
#   'release_date': '2023-10-18',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/5T9u88WBOgCsGk3GT30Z3r'},
#  {'album_id': '3D2j7JQjj9Kjc8sOfikmV6',
#   'album_name': 'Montagem Melodia Explosiva',
#   'release_date': '2024-09-06',
#   'total_tracks': 4,
#   'url': 'https://open.spotify.com/album/3D2j7JQjj9Kjc8sOfikmV6'}]

# %%
artist_df = pd.DataFrame(artist_info)

# %%
song_df = pd.DataFrame(song_info)

# %%
album_df = album_df.drop_duplicates(subset=['album_id'])

# %%
artist_df = artist_df.drop_duplicates(subset=['artist_id'])

# %%
song_df = song_df.drop_duplicates(subset=['song_id'])

# %%
album_df['release_date'] = pd.to_datetime(album_df['release_date'])

# %%
song_df['song_added'] = pd.to_datetime(song_df['song_added'])
